# %% [markdown]
# 布尔类型 bool
# 整数类型 int uint
# 浮点类型 float
# 复数 complex

# %%
import numpy as np

# %%
arr = np.array([1,0,-2,0], dtype='bool') #也可写作 dtype=np.bool
print(arr)

# %%
arr = np.array([1,0,127,0], dtype='int8') #127是int8上限 128会报错
print(arr)
