# %%
import torch
import numpy as np

# %%
tensor = torch.rand(5, 8)
print(tensor)
# 索引第2至3行
rows = tensor[1:3, :] #Python的索引从0开始，所以第2至3行是索引1:3
print(rows)
# 索引奇数列
odd = tensor[:, 1::2]
print(odd)
# 索引所有>0.6的元素
elements = tensor[tensor > 0.6]
print(elements)
# Out:
# tensor([[7.6875e-01, 6.2187e-01, 1.9782e-01, 4.8239e-01, 4.3310e-01, 6.3007e-01,
#          9.0182e-03, 3.5076e-01],
#         [9.3192e-01, 5.2542e-01, 5.9500e-01, 4.7453e-01, 4.2289e-01, 5.1276e-01,
#          1.9436e-01, 8.4139e-01],
#         [8.1164e-01, 9.6832e-01, 9.2130e-01, 7.8007e-01, 2.2068e-02, 9.7697e-01,
#          4.5217e-01, 4.6672e-01],
#         [1.3191e-01, 7.8761e-01, 1.7754e-01, 3.6788e-01, 3.9839e-01, 5.7352e-01,
#          4.2082e-01, 7.0767e-01],
#         [8.2665e-01, 1.2855e-01, 8.5735e-01, 9.0569e-04, 1.5339e-01, 5.5964e-01,
#          6.8846e-01, 2.1758e-01]])
# tensor([[0.9319, 0.5254, 0.5950, 0.4745, 0.4229, 0.5128, 0.1944, 0.8414],
#         [0.8116, 0.9683, 0.9213, 0.7801, 0.0221, 0.9770, 0.4522, 0.4667]])
# tensor([[6.2187e-01, 4.8239e-01, 6.3007e-01, 3.5076e-01],
#         [5.2542e-01, 4.7453e-01, 5.1276e-01, 8.4139e-01],
#         [9.6832e-01, 7.8007e-01, 9.7697e-01, 4.6672e-01],
#         [7.8761e-01, 3.6788e-01, 5.7352e-01, 7.0767e-01],
#         [1.2855e-01, 9.0569e-04, 5.5964e-01, 2.1758e-01]])
# tensor([0.7687, 0.6219, 0.6301, 0.9319, 0.8414, 0.8116, 0.9683, 0.9213, 0.7801,
#         0.9770, 0.7876, 0.7077, 0.8267, 0.8573, 0.6885])

# %%
x = torch.rand(1, 5)
print(x)
y = torch.rand(6, 1)
print(y)
# 按照广播机制相加
s = x + y
print(s)
t = x.expand(6, 5) + y.expand(6, 5) #需要x和y的形状相同，因此需要扩展为6*5
print(t)
# 将广播相加的结果赋值给x
x = t
print(x)
# Out:
# tensor([[0.1145, 0.6983, 0.4345, 0.1002, 0.6191]])
# tensor([[0.7731],
#         [0.9973],
#         [0.4756],
#         [0.8199],
#         [0.4530],
#         [0.3086]])
# tensor([[0.8876, 1.4714, 1.2076, 0.8734, 1.3922],
#         [1.1118, 1.6956, 1.4318, 1.0975, 1.6164],
#         [0.5901, 1.1738, 0.9101, 0.5758, 1.0947],
#         [0.9344, 1.5182, 1.2544, 0.9201, 1.4390],
#         [0.5675, 1.1513, 0.8875, 0.5532, 1.0721],
#         [0.4230, 1.0068, 0.7430, 0.4088, 0.9276]])
# tensor([[0.8876, 1.4714, 1.2076, 0.8734, 1.3922],
#         [1.1118, 1.6956, 1.4318, 1.0975, 1.6164],
#         [0.5901, 1.1738, 0.9101, 0.5758, 1.0947],
#         [0.9344, 1.5182, 1.2544, 0.9201, 1.4390],
#         [0.5675, 1.1513, 0.8875, 0.5532, 1.0721],
#         [0.4230, 1.0068, 0.7430, 0.4088, 0.9276]])
# tensor([[0.8876, 1.4714, 1.2076, 0.8734, 1.3922],
#         [1.1118, 1.6956, 1.4318, 1.0975, 1.6164],
#         [0.5901, 1.1738, 0.9101, 0.5758, 1.0947],
#         [0.9344, 1.5182, 1.2544, 0.9201, 1.4390],
#         [0.5675, 1.1513, 0.8875, 0.5532, 1.0721],
#         [0.4230, 1.0068, 0.7430, 0.4088, 0.9276]])

# %%
a1 = torch.rand(8, 8)
b1 = torch.rand(8, 8)
print(a1)
print(b1)
# 将张量转化为numpy的array
a2 = a1.numpy()
b2 = b1.numpy()
print(a2)
print(b2)
# 做矩阵相乘
result1 = np.dot(a2, b2)
print(result1)
# 将结果转化为pytorch下的张量类型
result2 = torch.from_numpy(result1)
print(result2)
# Out:
# tensor([[0.4303, 0.2530, 0.3558, 0.9162, 0.1621, 0.0038, 0.5375, 0.7063],
#         [0.5080, 0.8842, 0.0623, 0.4533, 0.6568, 0.6790, 0.6777, 0.2427],
#         [0.6854, 0.2603, 0.8067, 0.4940, 0.3307, 0.2434, 0.3686, 0.6528],
#         [0.3554, 0.9395, 0.8246, 0.9684, 0.0201, 0.2963, 0.2315, 0.5218],
#         [0.1315, 0.4302, 0.6447, 0.7672, 0.0810, 0.1533, 0.1201, 0.1420],
#         [0.3098, 0.7205, 0.2868, 0.5313, 0.1435, 0.1906, 0.5687, 0.0591],
#         [0.1486, 0.1086, 0.6129, 0.3810, 0.0805, 0.2963, 0.3291, 0.4481],
#         [0.5743, 0.2961, 0.7895, 0.3004, 0.7922, 0.6591, 0.3941, 0.0018]])
# tensor([[0.3033, 0.9441, 0.6075, 0.0282, 0.0845, 0.6154, 0.3461, 0.1514],
#         [0.2204, 0.3135, 0.1216, 0.3536, 0.9516, 0.5247, 0.8298, 0.0281],
#         [0.3658, 0.4496, 0.4484, 0.2692, 0.9831, 0.8017, 0.0711, 0.9896],
#         [0.4673, 0.1354, 0.7953, 0.4845, 0.9413, 0.0427, 0.3287, 0.8437],
#         [0.9414, 0.2949, 0.2962, 0.7514, 0.7981, 0.2118, 0.3799, 0.4906],
#         [0.5925, 0.7080, 0.7703, 0.1558, 0.7367, 0.6022, 0.8952, 0.5165],
#         [0.1355, 0.5395, 0.9403, 0.0877, 0.3187, 0.7990, 0.3510, 0.3653],
#         [0.4061, 0.6967, 0.4187, 0.7613, 0.8123, 0.1800, 0.0034, 0.4758]])
# [[0.43026024 0.25303245 0.35583186 0.9162343  0.16214669 0.00382745
#   0.5374515  0.7063301 ]
#  [0.5079875  0.8841965  0.0623129  0.45326036 0.65683615 0.67899287
#   0.6776977  0.24265826]
#  [0.68537724 0.2602849  0.8066503  0.4939742  0.330657   0.24343199
#   0.36863977 0.65278065]
#  [0.35543728 0.93954444 0.8246001  0.9684273  0.02011609 0.29626554
#   0.23153323 0.52176857]
#  [0.13146216 0.43016052 0.6446738  0.767201   0.08095479 0.15333188
#   0.12012297 0.1420204 ]
#  [0.30977535 0.72045696 0.28684747 0.531304   0.14350909 0.19056404
#   0.56869894 0.05914384]
#  [0.14858621 0.10855222 0.61288023 0.3810252  0.08047152 0.29631597
#   0.32914776 0.44809675]
#  [0.574258   0.29608303 0.7895432  0.30042422 0.7921624  0.659123
#   0.39414525 0.00177705]]
# [[0.30328017 0.94413376 0.60752755 0.02819604 0.08453715 0.61542416
#   0.34606516 0.15135032]
#  [0.22038966 0.31345266 0.12162268 0.35358852 0.9515821  0.5247281
#   0.8298478  0.02812129]
#  [0.36583555 0.44956774 0.44842958 0.26917124 0.98305196 0.8016817
#   0.07105637 0.98956054]
#  [0.46725172 0.13537121 0.79533106 0.48447222 0.941281   0.04272324
#   0.3286541  0.84369874]
#  [0.9413688  0.29493487 0.29623997 0.7514464  0.7980982  0.21184301
#   0.37990212 0.49058074]
#  [0.59249014 0.7079513  0.7703134  0.15575641 0.7366863  0.6022025
#   0.8952142  0.5164781 ]
#  [0.13553625 0.53951687 0.94032824 0.08765531 0.3187219  0.7990412
#   0.35097796 0.3652733 ]
#  [0.40606308 0.69672966 0.4187038  0.76131266 0.8123368  0.17998272
#   0.00338149 0.47583604]]
# [[1.2591094  1.6021568  2.032551   1.34856    2.3666935  1.3152018
#   0.9413331  1.8113155 ]
#  [1.7945222  2.0552485  2.2610683  1.4068071  2.8097732  1.9791306
#   2.158994   1.5817529 ]
#  [1.5616726  2.0817478  2.1080778  1.383473   2.654571   1.8548479
#   1.1479793  2.0592585 ]
#  [1.5067533  1.836016   2.1405635  1.5121545  3.3782442  1.8757786
#   1.6354448  2.2090018 ]
#  [0.96999955 0.9488204  1.3459688  0.9043888  2.1075678  1.0872538
#   0.9110747  1.5475873 ]
#  [0.9550194  1.2444451  1.575849   0.83049023 1.9780755  1.431565
#   1.3249856  1.2039566 ]
#  [0.94911975 1.2247165  1.4305692  0.8687547  1.8284303  1.1951592
#   0.7231533  1.4794618 ]
#  [1.8590149  1.9447558  2.0916507  1.2127849  2.6340957  2.0345705
#   1.628615   2.0038674 ]]
# tensor([[1.2591, 1.6022, 2.0326, 1.3486, 2.3667, 1.3152, 0.9413, 1.8113],
#         [1.7945, 2.0552, 2.2611, 1.4068, 2.8098, 1.9791, 2.1590, 1.5818],
#         [1.5617, 2.0817, 2.1081, 1.3835, 2.6546, 1.8548, 1.1480, 2.0593],
#         [1.5068, 1.8360, 2.1406, 1.5122, 3.3782, 1.8758, 1.6354, 2.2090],
#         [0.9700, 0.9488, 1.3460, 0.9044, 2.1076, 1.0873, 0.9111, 1.5476],
#         [0.9550, 1.2444, 1.5758, 0.8305, 1.9781, 1.4316, 1.3250, 1.2040],
#         [0.9491, 1.2247, 1.4306, 0.8688, 1.8284, 1.1952, 0.7232, 1.4795],
#         [1.8590, 1.9448, 2.0917, 1.2128, 2.6341, 2.0346, 1.6286, 2.0039]])
