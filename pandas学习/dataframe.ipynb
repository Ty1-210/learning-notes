# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 创建

# %%
#通过series创建
s1 = pd.Series([1,2,3,4,5])
s2 = pd.Series([6,7,8,9,10])
df = pd.DataFrame({'第一列':s1, '第二列':s2})
df.index = [1010,1011,1012,1013,1014] #不能在创建的时候改index dataframe和series索引必须对对齐
print(df)
print(type(df))
print(type(df['第一列']))
# Out:
#       第一列  第二列
# 1010    1    6
# 1011    2    7
# 1012    3    8
# 1013    4    9
# 1014    5   10
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
#通过字典创建
df = pd.DataFrame(
    {
        'ID':[1,2,3,4,5],
        'NAME':['A','B','C','D','E'],
        'AGE':[12,13,21,20,12]
    },
    index=[1010,1011,1012,1013,1014],
    columns=['ID','AGE','NAME'] #既可以改变列顺序，也可以达成对列显示的筛选
)
print(df)
# Out:
#       ID  AGE NAME
# 1010   1   12    A
# 1011   2   13    B
# 1012   3   21    C
# 1013   4   20    D
# 1014   5   12    E

# %% [markdown]
# 属性

# %%
print('行索引:',df.index)
print('列标签:',df.columns)
print('值:',df.values)
# Out:
# 行索引: Index([1010, 1011, 1012, 1013, 1014], dtype='int64')
# 列标签: Index(['ID', 'AGE', 'NAME'], dtype='object')
# 值: [[1 12 'A']
#  [2 13 'B']
#  [3 21 'C']
#  [4 20 'D']
#  [5 12 'E']]

# %%
print('维度:',df.ndim)
print('数据类型:',df.dtypes)
print('形状:',df.shape)
print('元素个数:',df.size)
# Out:
# 维度: 2
# 数据类型: ID       int64
# AGE      int64
# NAME    object
# dtype: object
# 形状: (5, 3)
# 元素个数: 15

# %%
print('转置:',df.T)
dft = df.T
print('行索引:',dft.index)
print('列标签:',dft.columns)
print('值:',dft.values)
# Out:
# 转置:      1010 1011 1012 1013 1014
# ID      1    2    3    4    5
# AGE    12   13   21   20   12
# NAME    A    B    C    D    E
# 行索引: Index(['ID', 'AGE', 'NAME'], dtype='object')
# 列标签: Index([1010, 1011, 1012, 1013, 1014], dtype='int64')
# 值: [[1 2 3 4 5]
#  [12 13 21 20 12]
#  ['A' 'B' 'C' 'D' 'E']]

# %%
print(df)
print(df.loc[1011:1014])
print(df.iloc[1:5])
#如果索引恰好是 0, 1, 2, 3...，那 loc 和 iloc 看起来确实一样。但一旦索引被打乱就不同
#e.g. 如果我的索引是1，2，4，3，5，loc[2:3]是2，4，3；iloc[2:3]是4
#loc左闭右闭 iloc左闭右开

print(df.loc[1012:1014,'AGE':'NAME']) #dataframe中可获取列，但先必须规定行
print(df.iloc[2:5,1:3])
# Out:
#       ID  AGE NAME
# 1010   1   12    A
# 1011   2   13    B
# 1012   3   21    C
# 1013   4   20    D
# 1014   5   12    E
#       ID  AGE NAME
# 1011   2   13    B
# 1012   3   21    C
# 1013   4   20    D
# 1014   5   12    E
#       ID  AGE NAME
# 1011   2   13    B
# 1012   3   21    C
# 1013   4   20    D
# 1014   5   12    E
#       AGE NAME
# 1012   21    C
# 1013   20    D
# 1014   12    E
#       AGE NAME
# 1012   21    C
# 1013   20    D
# 1014   12    E

# %%
print(df)
print(df.at[1010,'NAME'])
print(df.iat[0,2])
# Out:
#       ID  AGE NAME
# 1010   1   12    A
# 1011   2   13    B
# 1012   3   21    C
# 1013   4   20    D
# 1014   5   12    E
# A
# A

# %%
#访问数据
